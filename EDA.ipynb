# %% [markdown]
# # Data Load

# %%
import seaborn as sns
import pandas as pd
data=pd.read_csv("PJT002_test.csv")

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#            dt_of_fr bldng_us bldng_archtctr  bldng_cnt  bldng_ar   ttl_ar  \
# 0  2016-02-03 15:28      NaN            NaN          3      0.00     0.00
# 1  2016-03-17 18:25       공장         일반철골구조          2    915.75   903.75
# 2  2018-12-03 06:51      NaN            NaN          5   5523.87  9888.87
# 3  2015-03-29 23:37      NaN            NaN          8    667.20   914.40
# 4  2016-05-17 11:08      NaN            NaN          7   1050.06  1050.33
#
#     lnd_ar  dt_of_athrztn  ttl_grnd_flr  ttl_dwn_flr bldng_us_clssfctn  \
# 0      0.0            NaN           NaN          NaN               NaN
# 1   2660.0     20011228.0           1.0          0.0               공업용
# 2  13607.0            NaN           9.0          0.0               NaN
# 3      0.0            NaN           3.0          0.0               NaN
# 4      0.0            NaN           3.0          0.0               NaN
#
#    tmprtr  prcpttn  wnd_spd  wnd_drctn  hmdt  gas_engry_us_201401  \
# ...

# %%
data.shape
# Out:
# (2957, 180)

# %%
sns.distplot(data['bldng_cnt'])

# %%
pd.options.display.max_rows = 4000
data.isnull().sum()
# Out:
# dt_of_fr                           0
# bldng_us                         469
# bldng_archtctr                   460
# bldng_cnt                          0
# bldng_ar                           0
# ttl_ar                             0
# lnd_ar                             0
# dt_of_athrztn                    460
# ttl_grnd_flr                     343
# ttl_dwn_flr                      399
# bldng_us_clssfctn                687
# tmprtr                             1
# prcpttn                         2740
# wnd_spd                            1
# wnd_drctn                          4
# hmdt                               2
# gas_engry_us_201401              460
# ele_engry_us_201401              460
# gas_engry_us_201402              460
# ele_engry_us_201402              460
# gas_engry_us_201403              460
# ele_engry_us_201403              460
# gas_engry_us_201404              460
# ele_engry_us_201404              460
# gas_engry_us_201405              460
# ...
